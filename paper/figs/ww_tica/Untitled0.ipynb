# %%
matplotlib.rcParams['font.size'] = 22
from msmbuilder import io

# %%
ks = range(50, 1050, 50)
n=2
vl = np.array([np.loadtxt('MSMs/k%d_n%d/k/like_vol.dat' % (k, n)) for k in ks])
vc = np.array([np.loadtxt('MSMs/k%d_n%d/test/like_vol.dat' % (k, n)) for k in ks])
gl = np.array([np.loadtxt('MSMs/k%d_n%d/k/like_mvn.dat' % (k, n)) for k in ks])
gc = np.array([np.loadtxt('MSMs/k%d_n%d/test/like_mvn.dat' % (k, n)) for k in ks])
# Out:
# ---------------------------------------------------------------------------
# IOError                                   Traceback (most recent call last)
# <ipython-input-38-44166d410f7a> in <module>()
#       1 ks = range(50, 1050, 50)
#       2 n=2
# ----> 3 vl = np.array([np.loadtxt('MSMs/k%d_n%d/k/like_vol.dat' % (k, n)) for k in ks])
#       4 vl2 = np.array([np.loadtxt('MSMs/k%d_n%d/np/like_vol.dat' % (k, n)) for k in ks])
#       5 vc = np.array([np.loadtxt('MSMs/k%d_n%d/test/like_vol.dat' % (k, n)) for k in ks])
#
# /Users/schwancr/Installed/python/lib/python2.7/site-packages/numpy/lib/npyio.pyc in loadtxt(fname, dtype, comments, delimiter, converters, skiprows, usecols, unpack, ndmin)
#     727                 fh = iter(bz2.BZ2File(fname))
#     728             else:
# --> 729                 fh = iter(open(fname, 'U'))
#     730         else:
#     731             fh = iter(fname)
#
# IOError: [Errno 2] No such file or directory: 'MSMs/k700_n2/k/like_vol.dat'

# %%
plot(ks, gl)
plot(ks, gc)

# %%
# Out:
# ---------------------------------------------------------------------------
# IOError                                   Traceback (most recent call last)
# <ipython-input-42-01e5d621312f> in <module>()
# ----> 1 v0 = np.array([np.load('k%d/np/times100.npy' % k) for k in ks])
#       2 v1 = np.array([np.load('k%d/k/times100.npy' % k) for k in ks])
#       3
#       4 t0 = -50 / np.log(v0)
#       5 t1 = -50 / np.log(v1)
#
# /Users/schwancr/Installed/python/lib/python2.7/site-packages/numpy/lib/npyio.pyc in load(file, mmap_mode)
#     365     own_fid = False
#     366     if isinstance(file, basestring):
# --> 367         fid = open(file, "rb")
#     368         own_fid = True
#     369     elif isinstance(file, gzip.GzipFile):
#
# IOError: [Errno 2] No such file or directory: 'k50/np/times100.npy'
