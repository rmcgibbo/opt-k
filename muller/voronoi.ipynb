# %%
from mullermsm import muller

# %%
g10 = np.load('data/gens10.npy')
g50 = np.load('data/gens50.npy')
g100 = np.load('data/gens100.npy')
g250 = np.load('data/gens250.npy')
g800 = np.load('data/gens800.npy')

# %%
limits = [-3, 1.3, -1, 2.5]
muller.plot_v(*limits)
muller.plot_voronoi(g10, limits)
scatter(g10[:,0], g10[:,1], marker='*', s=100, c='white')
xlim(limits[:2])
ylim(limits[2:])
# Out:
# (-1, 2.5)

# %%
limits = [-3, 1.3, -1, 2.5]
muller.plot_v(*limits)
muller.plot_voronoi(g50, limits)
scatter(g50[:,0], g50[:,1], marker='*', s=100, c='white')
xlim(limits[:2])
ylim(limits[2:])
# Out:
# (-1, 2.5)

# %%
limits = [-3, 1.3, -1, 2.5]
muller.plot_v(*limits)
muller.plot_voronoi(g100, limits)
scatter(g100[:,0], g100[:,1], marker='*', s=100, c='white')
xlim(limits[:2])
ylim(limits[2:])
# Out:
# (-1, 2.5)

# %%
g100h = np.load('data/gens100hybrid.npy')
muller.plot_v(*limits)
muller.plot_voronoi(g100h, limits)
scatter(g100h[:,0], g100h[:,1], marker='*', s=100, c='white')
xlim(limits[:2])
ylim(limits[2:])
# Out:
# (-1, 2.5)

# %%
limits = [-3, 1.3, -1, 2.5]
muller.plot_v(*limits)
muller.plot_voronoi(g250, limits)
scatter(g250[:,0], g250[:,1], marker='*', s=100, c='white')
xlim(limits[:2])
ylim(limits[2:])
# Out:
# (-1, 2.5)

# %% [markdown]
# The hybrid generators are more central, and we would *expect* this model to have a higher log-likelihood!

# %%
limits = [-3, 1.3, -1, 2.5]
muller.plot_v(*limits)
muller.plot_voronoi(g800, limits)
scatter(g800[:,0], g800[:,1], marker='*', s=100, c='white')
xlim(limits[:2])
ylim(limits[2:])
# Out:
# (-1, 2.5)
